# %% [markdown]
# # Moving to Shallow Neural Networks
#
# In this tutorial, you'll implement a shallow neural network to classify digits ranging from 0 to 9. The dataset you'll use is quite famous, it's called 'MNIST' http://yann.lecun.com/exdb/mnist/. A French guy put it up, he's very famous in the DL comunity, he's called Yann Lecun and is now both head of the Facebook AI reseach program and head of something in the University of New York...
#
#
# ### First step
#
# As a first step, I invite you to discover what is MNIST. You might find [this notebook](https://nbviewer.jupyter.org/github/marc-moreaux/Deep-Learning-classes/blob/master/notebooks/dataset_MNIST.ipynb) to be usefull, but feel to browse the web.
#
# Once you get the idea, you can download the dataset

# %%
# Download the dataset in this directory (does that work on Windows OS ?)
#! wget http://deeplearning.net/data/mnist/mnist.pkl.gz
import os
os.getcwd()
os.chdir("deep_learning" )
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d98fb14c6cd4> in <module>()
#       3 import os
#       4 os.getcwd()
# ----> 5 os.chdir("D:\etudes\ECE\ING5\deep_learning" )
#       6 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\etudes\\ECE\\ING5\\deep_learning'

# %%
import pickle, gzip, numpy
import numpy as np

# Load the dataset
f = gzip.open('mnist.pkl.gz', 'rb')
train_set, valid_set, test_set = pickle.load(f,encoding='latin1')
f.close()

def to_one_hot(y, n_classes=10): # You might want to use this as some point...
    _y = np.zeros((len(y), n_classes))
    _y[np.arange(len(y)), y] = 1
    return _y

X_train, y_train = train_set[0], train_set[1]
X_valid, y_valid = valid_set[0], valid_set[1]
X_test,  y_test  = test_set[0],  test_set[1]
print('Training set', X_train.shape, y_train.shape)
print('Validation set', X_valid.shape, y_valid.shape)
print('Test set', X_test.shape, y_test.shape)
# Out:
# Training set (50000, 784) (50000,)
# Validation set (10000, 784) (10000,)
# Test set (10000, 784) (10000,)

# %% [markdown]
# ---
# # You can now implement a 2 layers NN
#
# Now that you have the data, you can build the a shallow neural network (SNN). I expect your SNN to have two layers.
#     - Layer 1 has 20 neurons with a sigmoid activation
#     - Layer 2 has 10 neurons with a softmax activation
#     - Loss is Negative Log Likelihood (wich is also the cross entropy)
#
# You'll need to comment your work such that I understand that you understand what you are doing

# %% [markdown]
# ### 1 - Define Parameters

# %%
image_size = 28
num_labels = 10

# HELPER 
def softmax(Z):
    """Z is a vector eg. [1,2,3]
    return: the vector softmax(Z) eg. [.09, .24, .67]
    """
    return np.exp(Z) / (np.exp(Z).sum(axis=0))

def sigmoid(Z):
    return 1 / (1 + np.exp(-Z))
def dsigmoid(Z):
    return np.dot(Z,(1-Z))

def accuracy(X, labels,W1,W2,b1,b2):
    tot = 0
    for i in range(len(X)):
        A1 = (layer(W1,X[i],b1))
        np.place(A1, np.isnan(A1),  np.random.normal(0.5,0.2))
        A2 = (sigmoid(A1))
        A2 = A2.reshape(20)
        np.place(A2, np.isnan(A2),  np.random.normal(0.5,0.2))
        Z = (layer(W2,A2,b2))
        np.place(Z, np.isnan(Z),  np.random.normal(0.5,0.2))
        prediction = softmax(Z)
    if (np.argmax(prediction) == np.argmax(labels)):
        tot = tot+1
    return ((100.0 * tot)/ len(X))
    

# Define the variables here (initialize the weights with the np.random.normal module):
W1, b1 =np.random.normal(0,0.1, (image_size*image_size,20)), np.random.normal(0,0.1, 20)
W2, b2 =np.random.normal(1,0.1, (20,num_labels)),np.random.normal(1,0.1, num_labels)

# %% [markdown]
# ### 2 - Define Model

# %%
def layer(W,X,b):
    return (np.dot(W.transpose(),X).transpose()+b)

def Pred(X,W1,W2,b1,b2):
    """Explanations 
    we predict what is the probability for X to be 1 of the 10 solutions y
    the SNN equation we use to predict the value of x:
    P = softmax(W2.T*sigmoid((W1.T*X+b1))+b2)
    The prediction process uses 2 layers:
    X -> A1 = W1.T*X+b1 -> A2 = sigmoid(A1) -> Z = W2.T*A2 + b2 -> p= softmax(z)
                LAYER 1     A1 btw 0&1            LAYER 2          Z btw 0&1
    
    Arguments:
        X: An input image (as a vector)(shape is <784,1>)
    Returns : a vector ???
    """
    #for it in range (len(X)):
    A1 = (layer(W1,X,b1))
    np.place(A1, np.isnan(A1),  np.random.normal(0.5,0.2))
        
    A2 = (sigmoid(A1))
    #for x in range(0,len(a1)):
    #   A2[x]=selu(A1[x])
    A2 = A2.reshape(20)
    np.place(A2, np.isnan(A2),  np.random.normal(0.5,0.2))
    Z = (layer(W2,A2,b2))
    np.place(Z, np.isnan(Z),  np.random.normal(0.5,0.2))
    train_prediction = softmax(Z)
    return train_prediction,Z,A2,A1

def loss(P, Y,i):
    """Explanations : 
    Compute the loss between prediction P and real value Y
    argmax(P(Y|X;W))=argmax TT(0...9|Xi;w) = argmin(sumi(sumj(Yij*ln(Pij)))) = L(W)
    Arguments:
        P: The prediction vector corresponding to an image (X^s)
        Y: The ground truth of an image
    Returns: a vector ???
    """
    #for i in range (0,len(Y)):
    #   for y in range (0,len())
    return np.sum(np.dot(Y[i],np.log(P)))

# %% [markdown]
# ### 3 - Define Derivatives

# %%
def dW1(L,A,W2,X):
    """Explanations :
    dL/dW1  = dL/dZ * dZ/dA2 * dA2/dA1 * dA1/dW1
            = (P-Y) * W2.T   * A2(1-A2)* X
    Returns: A vector which is the derivative of the loss with respect to W1
    """
    return  np.dot(X.transpose()[:,None], db1(L,A,W2).transpose()[None,:])


def db1(L,A,W2):
    """Explanations :
    dL/db1  = dL/dZ * dZ/dA2 * dA2/dA1 * dA1/b1
            = dL/dZ * d(W2.T*A2 + b2)/dA2 * d(sigmoid(A1))/dA1 * d(W1.T*X+b1)/b1
            = (P-Y) * W2.T * A2(1-A2) * 1
    Arguments:
        L is the loss af a sample (a scalar)
    Returns: A scalar which is the derivative of the Loss with respect to b1
    """
    return np.dot(L,np.dot(W2.transpose(),dsigmoid(A)))


def dW2(L,A):
    """Explanations :
    dL/dW2  = dL/dZ * dZ/dW2
            = dL/dZ * d(W2.T*A2 + b2)/d(W2)
            = (P-Y)A2
            = A2(P-Y).T
    """
    return np.dot(A[:,None],L[None,:])



def dL(P,Y,i):
    """
    Explanations :
    P = O(Z) = exp(Zj)/sumi(exp(Zi))     
    -> i=j:
    dPi/dZj = (exp(Zj)-(exp(Zj))^2)/sumi(exp(Zi))
    dPi/dZj = Pi(1-Pi)
    -> i=/=j :
    dPi/dZj = -exp(Zi)*exp(Zj)/(Sum(Pi)Sum(Pj))
    dPi/dZj = -Pi*Pj 
            = Pi(0-Pj)
    Hence,
    dOi(Z)/dZi = Pi(diracij - Pj) such that diracij = 1 if i=j;0 if i=/=j
    dL/dZi = Pi - Yi
    
    """
    return P-Y[i]

# %% [markdown]
# ### 4 - Train you model
#
# You may use Standard Gradient Descent (SGD) to train your model. (Experiment with many learning rates)

# %%
# Load the dataset
f = gzip.open('mnist.pkl.gz', 'rb')
train_set, valid_set, test_set = pickle.load(f,encoding='latin1')
f.close()
X_train, y_train = train_set[0], train_set[1]
X_valid, y_valid = valid_set[0], valid_set[1]
X_test,  y_test  = test_set[0],  test_set[1]
print('Training set', X_train.shape, y_train.shape)
print('Validation set', X_valid.shape, y_valid.shape)
print('Test set', X_test.shape, y_test.shape)
# Define the variables here (initialize the weights with the np.random.normal module):
W1, b1 =np.random.normal(0,0.1, (image_size*image_size,20)), np.random.normal(0,0.1, 20)
W2, b2 =np.random.normal(1,0.1, (20,num_labels)),np.random.normal(1,0.1, num_labels) 
alpha = 0.7
num_steps = 50000
train_set = 10000
valid_set = 1000
#####################################################################################################################
y_train = to_one_hot(y_train, n_classes=10)
y_valid = to_one_hot(y_valid, n_classes=10)
y_test = to_one_hot(y_test, n_classes=10)
j = 0

for step in range (1,num_steps):
    train_num = np.random.randint(train_set)
    
    #for i in range (0,50000):
    #np.place(p, np.isnan(p), np.random.normal(0.5,0.2))
    p,z,a2,a1, = Pred(X_train[train_num,:],W1,W2,b1,b2)
    l = loss(p,y_train,train_num)
    dl = dL(p,y_train,train_num)
    b2 = b2 - alpha*dl
    W2 = W2 - alpha*dW2(dl,a2)
    b1 = b1 - alpha*db1(dl,a2,W2)
    W1 = W1 - alpha*dW1(dl,a2,W2,X_train[np.random.randint(train_set),:])
    
    
    if (step % 100 == 0):
          print('Loss at step %d: %f' % (step, l))
          print('Training accuracy: %.1f%%' % accuracy(
           X_train[:valid_set,:] , y_train[:valid_set,:],W1,W2,b1,b2))

          print('Validation accuracy: %.1f%%' % accuracy(
            X_valid[:valid_set,:], y_valid[:valid_set,:],W1,W2,b1,b2))
print('Test accuracy: %.1f%%' % accuracy(X_test[:valid_set,:], y_test[:valid_set,:],W1,W2,b1,b2))
# Out:
# Training set (50000, 784) (50000,)
# Validation set (10000, 784) (10000,)
# Test set (10000, 784) (10000,)
# Loss at step 100: -14.922225
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 200: -15.308063
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 300: -14.729732
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 400: -15.153083
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 500: -14.409481
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 600: -19.851177
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 700: -15.443309
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 800: -14.915286
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 900: -14.769103
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1000: -14.852642
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1100: -15.307542
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1200: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1300: -14.895139
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1400: -19.130398
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1500: -14.720103
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 1600: -15.084465
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1700: -10.439006
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1800: -15.389887
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 1900: -14.855078
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2000: -14.854280
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2100: -14.126599
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 2200: -14.461807
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2300: -14.612052
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 2400: -14.670153
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2500: -14.851764
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2600: -15.366730
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2700: -18.418930
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2800: -14.555674
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 2900: -10.830304
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3000: -14.231937
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 3100: -11.015044
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3200: -14.799465
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 3300: -14.747167
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3400: -14.562851
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3500: -14.722945
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3600: -14.566200
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3700: -11.214234
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3800: -14.676442
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 3900: -18.167970
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4000: -15.331654
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4100: -15.079346
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4200: -14.772332
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4300: -18.205816
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4400: -14.549040
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4500: -14.985661
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4600: -18.268372
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4700: -14.439686
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 4800: -14.401558
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 4900: -14.237343
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5000: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5100: -14.861210
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5200: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 5300: -15.214377
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5400: -14.445102
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5500: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5600: -14.098442
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 5700: -11.343077
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 5800: -14.676239
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 5900: -14.589887
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6000: -14.854427
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6100: -14.497159
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 6200: -14.240206
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 6300: -15.065802
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6400: -15.096272
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6500: -14.712874
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6600: -14.721120
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6700: -17.498098
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6800: -14.926384
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 6900: -14.551336
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 7000: -11.692919
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7100: -11.602527
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7200: -14.279691
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 7300: -14.619422
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 7400: -14.805517
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7500: -14.559634
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7600: -14.824853
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7700: -17.792706
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7800: -14.960358
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 7900: -14.823890
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 8000: -14.769163
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 8100: -14.779344
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 8200: -14.453715
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 8300: -15.134955
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 8400: -14.552060
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 8500: -14.338282
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 8600: -14.225086
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 8700: -14.553095
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 8800: -14.580711
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 8900: -0.000005
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9000: -15.060735
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9100: -14.596551
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9200: -14.960947
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9300: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 9400: -14.869513
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9500: -14.691829
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 9600: -12.002887
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9700: -14.209872
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9800: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 9900: -14.811865
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10000: -14.559743
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 10100: -14.767797
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 10200: -17.597440
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10300: -0.000055
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10400: -14.932310
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10500: -14.472854
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10600: -14.563529
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10700: -17.292682
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10800: -14.675239
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 10900: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11000: -15.043221
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11100: -15.048026
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11200: -17.022033
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11300: -14.468674
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11400: -14.815259
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11500: -14.693757
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11600: -12.064286
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11700: -14.707058
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11800: -14.585962
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 11900: -14.357381
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12000: -14.923838
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12100: -17.433403
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12200: -14.523545
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 12300: -14.840482
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12400: -14.825579
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12500: -14.472402
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 12600: -11.998714
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 12700: -12.014431
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12800: -14.925189
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 12900: -12.163774
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13000: -14.527677
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 13100: -15.002448
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13200: -14.242858
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13300: -14.577785
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13400: -17.184747
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13500: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13600: -14.381381
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13700: -14.639491
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 13800: -17.172557
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 13900: -14.693815
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 14000: -14.478945
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 14100: -14.618932
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14200: -14.328444
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 14300: -12.281902
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14400: -15.087374
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14500: -14.403964
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14600: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14700: -12.384451
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14800: -12.295206
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 14900: -17.219443
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15000: -14.898064
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15100: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15200: -14.258345
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15300: -14.503308
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15400: -14.408686
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15500: -0.000037
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15600: -14.792550
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15700: -14.909814
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15800: -14.806324
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 15900: -16.945266
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16000: -15.021646
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16100: -15.140525
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16200: -14.593653
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16300: -14.908817
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16400: -14.924061
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16500: -14.323616
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 16600: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 16700: -15.135804
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16800: -15.074520
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 16900: -12.430091
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17000: -14.827827
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17100: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17200: -14.919853
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17300: -14.759355
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 17400: -14.571508
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17500: -14.405336
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17600: -14.583520
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 17700: -14.482515
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 17800: -12.344644
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 17900: -14.587999
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18000: -14.615030
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18100: -14.553953
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 18200: -14.292896
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 18300: -14.613334
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18400: -14.989559
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18500: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18600: -14.711892
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18700: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18800: -16.587481
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 18900: -14.423505
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19000: -12.613520
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19100: -15.114983
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19200: -14.494163
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19300: -14.575567
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 19400: -14.704082
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19500: -14.696053
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 19600: -14.710014
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19700: -15.111075
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 19800: -14.340258
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 19900: -16.952480
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 20000: -14.842041
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 20100: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 20200: -12.456339
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 20300: -14.904968
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 20400: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 20500: -12.525423
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 20600: -14.817577
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 20700: -14.614326
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 20800: -14.587417
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 20900: -14.906649
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21000: -16.716190
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21100: -16.805695
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21200: -14.968290
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21300: -12.495912
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21400: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21500: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21600: -14.499191
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21700: -14.773333
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21800: -12.702586
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 21900: -14.683051
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22000: -14.873507
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22100: -16.867578
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22200: -14.903280
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22300: -14.886927
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22400: -14.872557
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22500: -14.810116
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22600: -14.502928
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22700: -14.718467
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22800: -14.595649
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 22900: -15.092501
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23000: -14.609762
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23100: -12.695196
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23200: -14.687844
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23300: -12.964565
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23400: -16.806765
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23500: -14.431794
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23600: -12.787365
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23700: -12.801184
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23800: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 23900: -16.394962
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24000: -14.814061
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24100: -14.857205
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24200: -16.587504
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24300: -14.332340
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 24400: -14.524961
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24500: -14.515430
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 24600: -14.864277
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24700: -14.587135
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 24800: -14.672885
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 24900: -16.636744
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25000: -14.595820
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 25100: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25200: -14.441452
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25300: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25400: -14.320511
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25500: -0.000003
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 25600: -12.802956
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25700: -12.717836
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 25800: -14.453620
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 25900: -14.453630
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26000: -14.624892
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26100: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26200: -14.434704
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26300: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26400: -14.709523
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26500: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26600: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26700: -14.786851
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26800: -14.860986
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 26900: -16.553624
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27000: -14.769628
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27100: -14.616724
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27200: -15.071451
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27300: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27400: -14.855641
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27500: -14.601398
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 27600: -14.880772
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27700: -14.592334
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 27800: -14.449046
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 27900: -15.048044
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28000: -15.029400
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28100: -14.779648
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28200: -14.690249
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28300: -14.700873
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28400: -12.969345
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28500: -12.903889
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28600: -14.767876
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28700: -14.521293
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 28800: -12.915944
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 28900: -14.697111
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29000: -14.680063
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29100: -14.703042
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29200: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 29300: -16.401693
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29400: -14.464634
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29500: -14.716128
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 29600: -14.884717
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29700: -14.714574
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 29800: -13.181376
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 29900: -16.195773
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30000: -14.684648
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30100: -12.957593
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30200: -14.793686
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30300: -14.631970
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30400: -15.054992
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30500: -13.203511
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30600: -14.456728
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30700: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 30800: -14.794553
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 30900: -16.166081
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31000: -14.789435
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31100: -15.054224
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31200: -14.534999
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31300: -14.621429
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 31400: -14.681745
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31500: -14.346619
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31600: -14.715447
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 31700: -14.793961
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31800: -13.015280
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 31900: -15.051670
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32000: -14.452559
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32100: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32200: -13.090294
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32300: -14.383132
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 32400: -14.351995
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32500: -16.374173
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32600: -14.547135
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 32700: -14.863379
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32800: -14.852555
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 32900: -14.682814
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33000: -14.610974
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 33100: -14.626214
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33200: -14.761067
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33300: -14.609607
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 33400: -12.962162
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33500: -14.478504
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33600: -15.042261
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33700: -14.638629
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33800: -14.772937
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 33900: -14.790384
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34000: -14.639908
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34100: -14.784844
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34200: -16.092702
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34300: -14.541512
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34400: -14.857961
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34500: -16.246998
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34600: -13.098015
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34700: -16.395499
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34800: -16.398810
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 34900: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35000: -14.770735
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35100: -14.616970
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 35200: -13.105001
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35300: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35400: -16.062668
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35500: -13.186759
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35600: -14.713034
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35700: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35800: -14.788916
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 35900: -14.554885
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 36000: -14.859613
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36100: -14.929819
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36200: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36300: -14.376147
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 36400: -14.700003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36500: -14.801835
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36600: -0.000003
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 36700: -14.870637
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36800: -14.543154
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 36900: -15.014740
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37000: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37100: -14.373483
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37200: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37300: -16.313593
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37400: -14.870020
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37500: -14.548338
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37600: -13.237591
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 37700: -0.000003
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 37800: -14.710832
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 37900: -14.548733
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38000: -14.699773
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38100: -14.395711
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38200: -16.203300
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38300: -14.851629
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38400: -14.904287
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38500: -14.789962
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38600: -14.842885
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38700: -14.716291
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38800: -14.634051
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 38900: -14.902353
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39000: -14.702115
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39100: -14.649199
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39200: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39300: -16.124478
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39400: -14.768357
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39500: -15.969753
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39600: -14.648727
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39700: -14.841150
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 39800: -14.703056
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 39900: -14.763133
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40000: -14.559790
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 40100: -14.914825
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40200: -14.555527
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 40300: -14.841966
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40400: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40500: -14.653902
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40600: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40700: -14.862196
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40800: -14.861402
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 40900: -14.626094
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 41000: -14.842935
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41100: -14.717812
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41200: -16.076073
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41300: -14.894004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41400: -14.928602
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41500: -14.552056
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41600: -14.602409
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41700: -14.865644
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 41800: -14.559040
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 41900: -13.481140
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42000: -14.418869
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 42100: -14.509887
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42200: -14.716739
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42300: -13.281262
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42400: -0.000003
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 42500: -16.185621
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42600: -14.610247
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 42700: -13.497373
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42800: -16.041206
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 42900: -14.407862
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 43000: -14.779522
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43100: -14.766133
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43200: -14.609342
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 43300: -14.827606
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43400: -14.795684
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43500: -14.766685
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43600: -14.538134
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43700: -14.683610
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 43800: -14.715807
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 43900: -14.787284
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44000: -14.718843
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44100: -14.903840
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44200: -14.885133
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44300: -14.633142
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44400: -14.829121
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44500: -14.829439
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44600: -14.555994
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44700: -14.630299
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 44800: -14.782829
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 44900: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45000: -15.848291
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45100: -14.841319
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45200: -14.805342
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45300: -0.000004
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45400: -14.895330
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45500: -14.520358
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45600: -14.716519
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 45700: -14.804534
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45800: -14.632845
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 45900: -14.595869
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46000: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 46100: -14.838667
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46200: -14.571282
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 46300: -14.849690
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46400: -14.678978
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46500: -14.746940
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46600: -14.734437
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46700: -14.425155
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 46800: -15.982605
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 46900: -14.425651
# Training accuracy: 0.0%
# Validation accuracy: 0.1%
# Loss at step 47000: -14.556828
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47100: -14.678800
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47200: -14.828628
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47300: -15.974264
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47400: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47500: -13.395652
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47600: -14.971682
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47700: -14.556228
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47800: -14.975853
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 47900: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48000: -14.751274
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48100: -14.684399
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48200: -14.598230
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48300: -15.799402
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48400: -14.684926
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48500: -14.968544
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48600: -14.619203
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48700: -13.344419
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 48800: -14.765354
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 48900: -14.696282
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49000: -14.947594
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49100: -14.452226
# Training accuracy: 0.1%
# Validation accuracy: 0.0%
# Loss at step 49200: -13.468049
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49300: -15.930824
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49400: -0.000003
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49500: -14.839406
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49600: -14.764662
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49700: -14.820828
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49800: -14.699786
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Loss at step 49900: -16.046722
# Training accuracy: 0.0%
# Validation accuracy: 0.0%
# Test accuracy: 0.0%

# %%
# Out:
# /home/adrien/.local/lib/python3.5/site-packages/ipykernel_launcher.py:43: RuntimeWarning: divide by zero encountered in log

# %%
# Out:
# (10000,)

# %% [markdown]
# ### 5 - Test the accuracy of your model on the Test set

# %%
print('Test accuracy: %.1f%%' % accuracy(X_test[:valid_set,:], y_test[:valid_set,:],W1,W2,b1,b2))
# Out:
# Test accuracy: 0.0%

# %% [markdown]
# ---
# # You can now go Deeper
#
# Build a deeper model trained with SGD (You don't need to use the biases here)
#     - Layer 1 has 10 neurons with a sigmoid activation
#     - Layer 2 has 10 neurons with a sigmoid activation
#     - Layer 3 has 10 neurons with a sigmoid activation
#     - Layer 4 has 10 neurons with a sigmoid activation
#     - Layer 5 has 10 neurons with a sigmoid activation
#     - Layer 6 has 10 neurons with a softmax activation
#     - Loss is Negative Log Likelihood
#
# Is it converging ? Why ? What's wrong ?

# %%
W2.shape
# Out:
# (20, 10)

# %%
# Python
import tensorflow as tf
hello = tf.constant('Hello, TensorFlow!')
sess = tf.Session()
print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'
